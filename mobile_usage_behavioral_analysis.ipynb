# %% [markdown]
# About Dataset
#
# This dataset provides a comprehensive analysis of mobile device usage patterns and user behavior classification. It contains 700 samples of user data, including metrics such as app usage time, screen-on time, battery drain, and data consumption. Each entry is categorized into one of five user behavior classes, ranging from light to extreme usage, allowing for insightful analysis and modeling.
#
# Key Features:
#
# User ID: Unique identifier for each user.
#
# Device Model: Model of the user's smartphone.
#
# Operating System: The OS of the device (iOS or Android).
#
# App Usage Time: Daily time spent on mobile applications, measured in minutes.
#
# Screen On Time: Average hours per day the screen is active.
#
# Battery Drain: Daily battery consumption in mAh.
#
# Number of Apps Installed: Total apps available on the device.
#
# Data Usage: Daily mobile data consumption in megabytes.
#
# Age: Age of the user.
#
# Gender: Gender of the user (Male or Female).
#
# User Behavior Class: Classification of user behavior based on usage patterns (1 to 5).
#
# This dataset is ideal for researchers, data scientists, and analysts interested in understanding mobile user behavior and developing predictive models in the realm of mobile technology and applications. This Dataset was primarily designed to implement machine learning algorithms and is not a reliable source for a paper or article.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_csv('/content/mobile_usage_behavioral_analysis[1].csv')
df
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0          1   56    Male                   2.61                     7.15
# 1          2   46    Male                   2.13                    13.79
# 2          3   32  Female                   7.28                     4.50
# 3          4   25  Female                   1.20                     6.29
# 4          5   38    Male                   6.31                    12.59
# ..       ...  ...     ...                    ...                      ...
# 995      996   41  Female                   3.58                    12.46
# 996      997   32    Male                   9.65                    10.51
# 997      998   46  Female                  11.68                    10.06
# 998      999   25    Male                   3.89                    10.78
# 999     1000   22  Female                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   User_ID                       1000 non-null   int64
#  1   Age                           1000 non-null   int64
#  2   Gender                        1000 non-null   object
#  3   Total_App_Usage_Hours         1000 non-null   float64
#  4   Daily_Screen_Time_Hours       1000 non-null   float64
#  5   Number_of_Apps_Used           1000 non-null   int64
#  6   Social_Media_Usage_Hours      1000 non-null   float64
#  7   Productivity_App_Usage_Hours  1000 non-null   float64
#  8   Gaming_App_Usage_Hours        1000 non-null   float64
#  9   Location                      1000 non-null   object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 78.2+ KB

# %%
df.isnull().sum()
# Out:
# User_ID                         0
# Age                             0
# Gender                          0
# Total_App_Usage_Hours           0
# Daily_Screen_Time_Hours         0
# Number_of_Apps_Used             0
# Social_Media_Usage_Hours        0
# Productivity_App_Usage_Hours    0
# Gaming_App_Usage_Hours          0
# Location                        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.describe()
# Out:
#            User_ID          Age  Total_App_Usage_Hours  \
# count  1000.000000  1000.000000            1000.000000
# mean    500.500000    38.745000               6.405670
# std     288.819436    12.186734               3.134855
# min       1.000000    18.000000               1.000000
# 25%     250.750000    28.000000               3.590000
# 50%     500.500000    40.000000               6.455000
# 75%     750.250000    50.000000               9.122500
# max    1000.000000    59.000000              11.970000
#
#        Daily_Screen_Time_Hours  Number_of_Apps_Used  Social_Media_Usage_Hours  \
# count              1000.000000           1000.00000               1000.000000
# mean                  7.696310             16.64700                  2.456330
# std                   3.714187              7.61961                  1.439525
# min                   1.010000              3.00000                  0.000000
# ...

# %%
print(df['Gender'].value_counts())
sns.histplot(df['Age'], kde=True)
# Out:
# Gender
# Male      517
# Female    483
# Name: count, dtype: int64
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sns.histplot(df['Daily_Screen_Time_Hours'], kde=True)
plt.title('Daily_Screen_Time')
plt.show()


sns.barplot(x='Gender', y='Daily_Screen_Time_Hours', data=df)
plt.title('Total Screen_Time Rate by Sex')
plt.show()

sns.scatterplot(x='Age', y='Daily_Screen_Time_Hours', data=df,hue='Daily_Screen_Time_Hours')
plt.show()

# %%
sns.pairplot(df,hue='Daily_Screen_Time_Hours')
plt.show()

# %%
df.hist(edgecolor='black',figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'User_ID'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Total_App_Usage_Hours'}>],
#        [<Axes: title={'center': 'Daily_Screen_Time_Hours'}>,
#         <Axes: title={'center': 'Number_of_Apps_Used'}>,
#         <Axes: title={'center': 'Social_Media_Usage_Hours'}>],
#        [<Axes: title={'center': 'Productivity_App_Usage_Hours'}>,
#         <Axes: title={'center': 'Gaming_App_Usage_Hours'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['Gender'] = labelencoder.fit_transform(df['Gender'])
df['Location'] = labelencoder.fit_transform(df['Location'])

# %%
df
# Out:
#      User_ID  Age  Gender  Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# 0          1   56       1                   2.61                     7.15
# 1          2   46       1                   2.13                    13.79
# 2          3   32       0                   7.28                     4.50
# 3          4   25       0                   1.20                     6.29
# 4          5   38       1                   6.31                    12.59
# ..       ...  ...     ...                    ...                      ...
# 995      996   41       0                   3.58                    12.46
# 996      997   32       1                   9.65                    10.51
# 997      998   46       0                  11.68                    10.06
# 998      999   25       1                   3.89                    10.78
# 999     1000   22       0                   3.99                     7.05
#
#      Number_of_Apps_Used  Social_Media_Usage_Hours  \
# ...

# %%
corr_matrix = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=True, fmt='0.01f', cmap='coolwarm',annot_kws=None, linewidths=0, robust=True,square=True)
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix
# Out:
#                                User_ID       Age    Gender  \
# User_ID                       1.000000 -0.028576 -0.018055
# Age                          -0.028576  1.000000 -0.052271
# Gender                       -0.018055 -0.052271  1.000000
# Total_App_Usage_Hours        -0.010570 -0.003319  0.005434
# Daily_Screen_Time_Hours       0.020941 -0.017639  0.016623
# Number_of_Apps_Used          -0.001214 -0.002081  0.006701
# Social_Media_Usage_Hours     -0.002608 -0.008324 -0.042591
# Productivity_App_Usage_Hours  0.002207  0.005848  0.019108
# Gaming_App_Usage_Hours       -0.003514 -0.012969 -0.007630
# Location                      0.070221 -0.014906 -0.014629
#
#                               Total_App_Usage_Hours  Daily_Screen_Time_Hours  \
# User_ID                                   -0.010570                 0.020941
# Age                                       -0.003319                -0.017639
# Gender                                     0.005434                 0.016623
# ...

# %%
sor = df.corr()['Daily_Screen_Time_Hours']
sor = sor.sort_values(ascending=False)
sor
# Out:
# Daily_Screen_Time_Hours         1.000000
# Productivity_App_Usage_Hours    0.033206
# Social_Media_Usage_Hours        0.031773
# User_ID                         0.020941
# Number_of_Apps_Used             0.016835
# Gender                          0.016623
# Total_App_Usage_Hours           0.002948
# Gaming_App_Usage_Hours         -0.012984
# Age                            -0.017639
# Location                       -0.018628
# Name: Daily_Screen_Time_Hours, dtype: float64

# %%
df.drop(columns=['User_ID'], inplace=True)
df.drop(columns=['Total_App_Usage_Hours'], inplace=True)
df.drop(columns=['Gaming_App_Usage_Hours'], inplace=True)
df.drop(columns=['Location'], inplace=True)
df.drop(columns=['Social_Media_Usage_Hours'], inplace=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.plot(kind='box',subplots=True,layout=(3,5),figsize=(13,15),color='blue',patch_artist=True)
plt.suptitle('Boxplots of Mobile Device Usage',fontsize=16)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
independet_feature = ['Age','Gender','Number_of_Apps_Used','Productivity_App_Usage_Hours']
dependet_feature = ['Daily_Screen_Time_Hours']
x = df[independet_feature]
y = df[dependet_feature]

# %%
df
# Out:
#      Age  Gender  Daily_Screen_Time_Hours  Number_of_Apps_Used  \
# 0     56       1                     7.15                   24
# 1     46       1                    13.79                   18
# 2     32       0                     4.50                   11
# 3     25       0                     6.29                   21
# 4     38       1                    12.59                   14
# ..   ...     ...                      ...                  ...
# 995   41       0                    12.46                   13
# 996   32       1                    10.51                   11
# 997   46       0                    10.06                    9
# 998   25       1                    10.78                   15
# 999   22       0                     7.05                    4
#
#      Productivity_App_Usage_Hours
# 0                            0.55
# 1                            4.42
# 2                            1.71
# 3                            3.42
# ...

# %%
# Create and fit the scaler
scaler = StandardScaler()
scaler.fit(x)

# Transform the data
X_scaled = scaler.transform(x)
# X_test_scaled = scaler.transform(X_test)

# %%
x
# Out:
#      Age  Gender  Number_of_Apps_Used  Productivity_App_Usage_Hours
# 0     56       1                   24                          0.55
# 1     46       1                   18                          4.42
# 2     32       0                   11                          1.71
# 3     25       0                   21                          3.42
# 4     38       1                   14                          0.13
# ..   ...     ...                  ...                           ...
# 995   41       0                   13                          2.44
# 996   32       1                   11                          1.02
# 997   46       0                    9                          3.13
# 998   25       1                   15                          1.79
# 999   22       0                    4                          4.98
#
# [1000 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
                                                    random_state=42)#to take  the same 80% and 20% of data(same function of seed)

# %%
y
# Out:
#      Daily_Screen_Time_Hours
# 0                       7.15
# 1                      13.79
# 2                       4.50
# 3                       6.29
# 4                      12.59
# ..                       ...
# 995                    12.46
# 996                    10.51
# 997                    10.06
# 998                    10.78
# 999                     7.05
#
# [1000 rows x 1 columns]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape )
# Out:
# (800, 4)
# (200, 4)
# (800, 1)
# (200, 1)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[7.71631602],
#        [8.03483512],
#        [7.48988153],
#        [7.8351222 ],
#        [7.33418552],
#        [7.29579769],
#        [7.23704519],
#        [7.77463568],
#        [7.94218473],
#        [7.84657304],
#        [7.78397031],
#        [7.76358168],
#        [7.86975745],
#        [7.40416361],
#        [7.90827238],
#        [7.75258671],
#        [7.60176942],
#        [7.43357133],
#        [7.55329117],
#        [7.78936532],
#        [7.38315318],
#        [7.50030118],
#        [7.62217885],
#        [7.52636026],
#        [7.68261913],
#        [7.37486313],
#        [7.51832268],
#        [7.60461982],
#        [7.84121814],
#        [7.88932697],
#        [7.72996067],
#        [7.61627554],
#        [7.69907253],
#        [7.21087666],
#        [8.11604713],
#        [8.05440997],
#        [7.5363851 ],
#        [8.08507116],
#        [7.60969682],
#        [7.73647941],
#        [7.50446528],
#        [7.65728781],
#        [7.54722703],
# ...

# %%
mae = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

# %%
print('Mean Squared Error:',mae)
print('R2 Score:',r2)
# Out:
# Mean Squared Error: 14.165642524719178
# R2 Score: -0.008680962401172554

# %%
# print(model.intercept_)
# print(model.coef_)

# %%
# from sys import getfilesystemencodeerrors
# Age= float(input('Enter Age:'))
# Gender= float(input('Enter Gender:'))
# Number_of_Apps_Used= float(input('Enter Number_of_Apps_Used:'))
# Productivity_App_Usage_Hours= float(input('Enter Productivity_App_Usage_Hours:'))
# user_input = [[Age,Gender,Number_of_Apps_Used,Productivity_App_Usage_Hours]]
# AQI = model.predict(user_input)
# print('The Predicted AQI',AQI)

# %%
df
# Out:
#      Age  Gender  Daily_Screen_Time_Hours  Number_of_Apps_Used  \
# 0     56       1                     7.15                   24
# 1     46       1                    13.79                   18
# 2     32       0                     4.50                   11
# 3     25       0                     6.29                   21
# 4     38       1                    12.59                   14
# ..   ...     ...                      ...                  ...
# 995   41       0                    12.46                   13
# 996   32       1                    10.51                   11
# 997   46       0                    10.06                    9
# 998   25       1                    10.78                   15
# 999   22       0                     7.05                    4
#
#      Productivity_App_Usage_Hours
# 0                            0.55
# 1                            4.42
# 2                            1.71
# 3                            3.42
# ...

# %%
df.shape
# Out:
# (1000, 5)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x=y_pred,y=y_test)
plt.xlabel('Predicted Daily_Screen_Time_Hours')
plt.ylabel('Actual Daily_Screen_Time_Hours')
plt.title('Actual vs Predicted Daily_Screen_Time_Hours')
plt.show()
